# %% [markdown]
# # 0. Initialize

# %% [markdown]
# ## 0.1. Import Libraries

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os, sys, glob
import gzip
import random
import tqdm
import json
import numpy as np
import pandas as pd
pd.set_option("display.max_columns", None)

from IPython import display
import matplotlib as mpl
from matplotlib import pyplot as plt
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## 0.2. DEFINE VARIABLES

# %%
DATA_PATH = '/content/drive/MyDrive/CS412'

ROUND = 2 # This project will have 3 rounds of predictions: 1,2,3
STUDENT_ID = '25431'
PROJECT_CODE = 'CS4128e359db85abb' # Same code for the annotation eg. CS412xxxxx

# %% [markdown]
# ## 0.3. Read Training & Evaluation Data

# %% [markdown]
# ### 0.3.1. Get the labels for tweets

# %%
#trainingTweetDf = pd.read_csv('{}training-tweet.csv'.format(DATA_PATH))
trainingTweetDf = pd.read_csv('training-tweet.csv', dtype={'tweet_id': str, 'isPolitical': str})
trainingTweetDf
# Out:
#                  tweet_id isPolitical
# 0     1418828259614236672          No
# 1     1424439289753083911          No
# 2     1354305766644199427         Yes
# 3     1438890637282193408         Yes
# 4     1397543048452591616          No
# ...                   ...         ...
# 2995  1416144676990722053         Yes
# 2996  1466793383788220421         Yes
# 2997  1448350353439744003         Yes
# 2998  1423327989044072453         Yes
# 2999  1417253447347458052          No
#
# [3000 rows x 2 columns]

# %%
trainingTweetDf.isPolitical.value_counts()
# Out:
# No     1509
# Yes    1491
# Name: isPolitical, dtype: int64

# %% [markdown]
# ### 0.3.2. Get the labels for users

# %%
#trainingUserDf = pd.read_csv('{}training-user.csv'.format(DATA_PATH))
trainingUserDf = pd.read_csv('training-user.csv')
trainingUserDf
# Out:
#           screen_name     isBot
# 0        faracyaziyor        No
# 1          elifgibirt        No
# 2        buocguldurdu        No
# 3        __baba1yaga_        No
# 4     hakanyilmazcebi        No
# ...               ...       ...
# 2995  kupakralicesi53        No
# 2996  muhamme44063672        No
# 2997         galaopta  Not sure
# 2998           hygea0        No
# 2999        ama_ensar        No
#
# [3000 rows x 2 columns]

# %%
trainingUserDf.isBot.value_counts()
# Out:
# No          2363
# Yes          401
# Not sure     236
# Name: isBot, dtype: int64

# %% [markdown]
# ### 0.3.3. Expand your dataset with metadata and tweets

# %%
# You can also expand training data by downloading your own labeled datasets following the link
# Download the documents under "Link to training data"

print('http://www.onurvarol.com/AnnotationTwitterTR/reports/report_{}.html'.format(PROJECT_CODE))
# Out:
# http://www.onurvarol.com/AnnotationTwitterTR/reports/report_CS4128e359db85abb.html

# %% [markdown]
# ## 1. Landing Page

# %%
display.Image("https://i.imgur.com/IHvQHIf.png")

# %% [markdown]
# ## 2. Link for Downloading Training Data
#
# At the bottom of the page, you will see the **LINK FOR FILES**

# %%
display.Image("https://i.imgur.com/t19vAjr.png")

# %% [markdown]
# ## 3. Google Drive
#
# You can download the following project files from Google Drive
#
# - **user_profiles.jsons.gz**: Contains user metadata for bot detection phase of your project
# - **user_tweets.jsons.gz**: Contains at most 200 tweets of the above mentioned users'
# - **tweet_metadata.jsons.gz**: Contains tweets and their metadata for the political tweet detection of your project

# %%
display.Image("https://i.imgur.com/7FjWPLi.png")

# %% [markdown]
# # 1. EXTRACT FEATURES
# Under *1.1. Political Tweet Detection* and *1.2. Bot Detection*, we firstly collect raw data for processing. We then combine some of them (total_interactions = num_favorites + num_retweets) or use them to extract features (whether the tweet has one of the political entities @meralaksener, @kilicdarogluk etc.).
#
# We expect you to collect more raw data from **tweet_metadata**, **user_profiles** and **user_tweets** files by creating a function as shown in below examples such as *check_if_retweet()* and using it while iterating over data as shown under *Merge Collected Features*.
#
# We also expect you to create new variables as much as you can from the data in order to make your predictions more accurate. For example, you may want to check:
#
# - The tweet sources that a user frequently uses
# - Whether the user is a verified account or not
#
# ...
#
# to assess whether **a user is a bot or not** and whether **a tweet is political or not**.

# %%
PATH_TO_DOWNLOADED = 'training-tweet.csv'

# %% [markdown]
# ## 1.1. Political Tweet Detection
# This part stands for the feature extraction of tweets. We start with collecting the raw data from *tweet_metadata*, then use some of them to extract features.

# %% [markdown]
# ### 1.1.1. Get Raw Data

# %% [markdown]
# #### 1.1.1.1. Check if Retweet

# %%
def check_if_retweet(tweet_metadata_line):
    is_retweet = 0
    retweeted_username = None

    try:
        tweet_metadata_line['retweeted_status']
        retweeted_username = tweet_metadata_line['retweeted_status']['user']['screen_name'].lower()
        is_retweet = 1

    except KeyError:
        pass

    return is_retweet, retweeted_username

# %% [markdown]
# #### 1.1.1.2. Get Tweet Text

# %%
def get_tweet_text(tweet_metadata_line):
    text = tweet_metadata_line['text']
    
    return text

# %% [markdown]
# #### 1.1.1.3. Get Tweet ID

# %%
def get_tweet_id(tweet_metadata_line):
    id_str = tweet_metadata_line['id_str']
    
    return id_str

# %% [markdown]
# #### 1.1.1.4. Get Number of Mentions and Hashtags

# %%
def get_number_mentions_hashtags(tweet_metadata_line):
    num_mentions = len(tweet_metadata_line['entities']['user_mentions'])
    num_hashtags = len(tweet_metadata_line['entities']['hashtags'])

    return num_mentions, num_hashtags

# %% [markdown]
# #### 1.1.1.5. Get Number of Retweets and Favorites

# %%
def get_number_retweets_favorites(tweet_metadata_line):
    retweet_count = tweet_metadata_line['retweet_count']
    favorite_count = tweet_metadata_line['favorite_count']
    
    return retweet_count, favorite_count

# %% [markdown]
# #### 1.1.1.6. Get User Info

# %%
def get_user_info(tweet_metadata_line):
    id = tweet_metadata_line['user']['id_str']
    screen_name = tweet_metadata_line['user']['screen_name'].lower()
    description = tweet_metadata_line['user']['description']

    return id, screen_name, description

# %% [markdown]
# ### 1.1.2. Derive Manually Crafted Features

# %% [markdown]
# #### 1.1.2.1. Check for political entity in text

# %%
def check_political_ent(text):
    
    # the list below can be modified and some new names may be added (or removed)
    list_of_entities = ['meral_aksener', 'kilicdarogluk', 'vekilince', 'RTErdogan', 'MevlutCavusoglu', 'umitozdag', 'ekrem_imamoglu', 'mansuryavas06', 'drfahrettinkoca', 'suleymansoylu', 'tcbestepe', 'MHP_Bilgi', 'dbdevletbahceli', 'Akparti', 'iyiparti', 'Ahmet_Davutoglu','herkesicinCHP', 'zaferpartisi', 'GelecekPartiTR' ]
    
    entities_in_text = [ent for ent in list_of_entities if ent.lower() in text.lower()]
    number_entities = len(entities_in_text)

    return number_entities

# %% [markdown]
# #### 1.1.2.2. Number of total interactions

# %%
def total_interactions(retweet_count, favorite_count):
    total_num_interactions = retweet_count + favorite_count
    
    return total_num_interactions

# %% [markdown]
# ### 1.1.2. Collect data using the functions above and transform into a Pandas DataFrame

# %%
dfPolitical = {'tweet_id':[],
              'is_retweet':[],
              'retweeted_username':[],
              'text':[],
              'num_mentions':[],
              'num_hashtags':[],
              'num_retweets':[],
              'num_favorites':[],
              'user_id':[],
              'user_screen_name':[],
              'user_description':[],
              'num_political_entities':[],
              'total_interactions':[]}


with gzip.open(f"/content/drive/MyDrive/CS412-Project-Files/tweet_metadata.jsons.gz", "rb") as f:
    for line in f:
        line = json.loads(line)
        
        # raw data:
        id_str = get_tweet_id(line)
        is_retweet, retweeted_username = check_if_retweet(line)
        text = get_tweet_text(line)
        num_mentions, num_hashtags = get_number_mentions_hashtags(line)
        retweet_count, favorite_count = get_number_retweets_favorites(line)
        user_id_str, screen_name, user_description = get_user_info(line)

        # manually crafted data:
        num_political_entities = check_political_ent(text)
        total_num_interactions = total_interactions(retweet_count, favorite_count)

        dfPolitical['tweet_id'].append(id_str)
        dfPolitical['is_retweet'].append(is_retweet)
        dfPolitical['retweeted_username'].append(retweeted_username)
        dfPolitical['text'].append(text)
        dfPolitical['num_mentions'].append(num_mentions)
        dfPolitical['num_hashtags'].append(num_hashtags)
        dfPolitical['num_retweets'].append(retweet_count)
        dfPolitical['num_favorites'].append(favorite_count)
        dfPolitical['user_id'].append(user_id_str)
        dfPolitical['user_screen_name'].append(screen_name)
        dfPolitical['user_description'].append(user_description)
        dfPolitical['num_political_entities'].append(num_political_entities)
        dfPolitical['total_interactions'].append(total_num_interactions)

# %%
dfPolitical = pd.DataFrame(dfPolitical)
dfPolitical
# Out:
#                   tweet_id  is_retweet retweeted_username  \
# 0      1416676063216799754           0               None
# 1      1445677417150889986           1     ekrem_imamoglu
# 2      1456638729620230149           1          yenisafak
# 3      1451295314074341381           1     ekrem_imamoglu
# 4      1440610747134844929           1          umitozdag
# ...                    ...         ...                ...
# 32997  1439639972177489926           1     deryayanikashb
# 32998  1467519965473423362           1      kilicdarogluk
# 32999  1423666826282668035           1          rterdogan
# 33000  1417025303894007810           1          thetubaca
# 33001  1418594874836848649           1          kasapoglu
#
#                                                     text  num_mentions  \
# 0      @Murat_ide @meral_aksener Bu bu büyük millet k...             2
# 1      RT @ekrem_imamoglu: Geldikleri gibi gittiler… ...             1
# 2      RT @yenisafak: İYİ PARTİLİ TÜRKKAN ŞEHİT AĞABE...             1
# 3      RT @ekrem_imamoglu: Bu gece ben: ❤️💛\nTebrikle...             1
# 4      RT @umitozdag: Sayın Bakan demek yüzmeyi öğren...             1
# ...                                                  ...           ...
# 32997  RT @deryayanikashb: AK Parti Çanakkale İl Başk...             1
# 32998  RT @kilicdarogluk: Türkiye Barolar Birliği 36....             1
# 32999  RT @RTErdogan: Geleceğe Nefes kampanyasıyla he...             1
# 33000  RT @thetubaca: Hasta tutuklu Ekim Polat açlık ...             3
# 33001  RT @kasapoglu: Haydi Bismillah! #Tokyo2020’dek...             1
#
#        num_hashtags  num_retweets  num_favorites              user_id  \
# 0                 0             0              0  1368124787009216516
# 1                 0          6706              0  1263130166961864705
# 2                 0          1545              0           2958652582
# 3                 0          7470              0  1447285927471112194
# 4                 0           745              0            379944275
# ...             ...           ...            ...                  ...
# 32997             0            48              0            165689533
# 32998             0          4438              0            408719429
# 32999             0         14311              0  1004379711890485248
# 33000             0            16              0  1049663929348222985
# 33001             1           439              0   719802634819997696
#
#       user_screen_name                                   user_description  \
# 0      murtaza91000878
# 1      hasanak11633015                                       64 Jahre alt
# 2          buyukdogu58                                Katılıyorum: RT+FAV
# 3            gskaya444
# 4            cerenncan
# ...                ...                                                ...
# 32997      sezayicimen  İst.Aydın Üniversitesi Mahalli İdareler ve Yer...
# 32998         sdiplen1       Hepimiz birileri için kurallarımızı çiğnedik
# 32999       soguzsoylu                   AK Parti Yumurtalık İlçe Başkanı
# 33000      mhmt_ckmk04     667 ile yılları çalınan gurebadan bir garip...
# 33001       trguresfed  Turkish Wrestling Federation Official twitter ...
#
#        num_political_entities  total_interactions
# 0                           1                   0
# 1                           1                6706
# 2                           0                1545
# 3                           1                7470
# 4                           1                 745
# ...                       ...                 ...
# 32997                       0                  48
# 32998                       1                4438
# 32999                       1               14311
# 33000                       0                  16
# 33001                       0                 439
#
# [33002 rows x 13 columns]

# %% [markdown]
# ## 1.2. From Users

# %% [markdown]
# ### 1.2.1. Get user metadata from user_profiles.jsons.gz

# %% [markdown]
# #### 1.2.1.1. Get user info metadata

# %%
def get_user_info_metadata(user_metadata_line):
    
    user_id = user_metadata_line['id_str']
    user_name = user_metadata_line['name']
    user_screen_name = user_metadata_line['screen_name'].lower()
    user_location = user_metadata_line['location']
    user_description = user_metadata_line['description']
    user_followers_count = user_metadata_line['followers_count']
    user_friends_count = user_metadata_line['friends_count']
    
    dictionary = {'user_id':user_id, 'user_name': user_name, 'user_screen_name':user_screen_name, 'user_location':user_location,
     'user_description':user_description, 'user_followers_count':user_followers_count, 'user_friends_count':user_friends_count}

    return dictionary

# %% [markdown]
# #### 1.2.1.2. Get followers/(followers+friends) ratio

# %%
def get_followers_all_ratio(user_followers_count, user_friends_count):
    
    if user_friends_count + user_followers_count == 0:
        followers_all_ratio = 0

    else:
        followers_all_ratio =  user_followers_count / (user_friends_count + user_followers_count)

    return followers_all_ratio

# %% [markdown]
# #### 1.2.1.3. Get description length

# %%
def get_desc_len(user_description):
    
    description_len = len(user_description)

    return description_len

# %%
##Get Verified account For DfBot

def check_verified(user_metadata_line):
  is_verified = 0
  try:
    if(user_metadata_line['verified'] == True):
      is_verified = 1
  except KeyError:
    pass
  return is_verified

# %%
dfBot = {'user_id':[],
         'user_name':[],
         'user_screen_name':[],
         'user_location':[],
         'user_description':[],
         'user_followers_count':[],
         'user_friends_count':[],
         'description_len':[],
         'is_verified':[],
         'followers_to_all_ratio':[]}

with gzip.open(f"/content/drive/MyDrive/CS412-Project-Files/user_profiles.jsons.gz", "rb") as f:
    for line in f:
        line = json.loads(line)

        dictionary = get_user_info_metadata(line)
        for k,v in dictionary.items():
            dfBot[k].append(v)

        is_verified = check_verified(line)

        # manually crafted data:
        description_len = get_desc_len(dictionary['user_description'])
        dfBot['description_len'].append(description_len)
        
        followers_all_ratio = get_followers_all_ratio(dictionary['user_followers_count'], 
                                                      dictionary['user_friends_count'])

        dfBot['followers_to_all_ratio'].append(followers_all_ratio)
        dfBot['is_verified'].append(is_verified)

# %%
dfBot = pd.DataFrame(dfBot)
dfBot
# Out:
#                    user_id                                         user_name  \
# 0      1195008426784493571                                      Mesut Demir🎨
# 1       912738858437050369                                       AdnanToprak
# 2               2490178497  Nejla ÖNÇIRAK😷 bilgin yoksa , fikrin de olmasın👍
# 3                161774611                             Tek Kişilik Muhalefet
# 4      1349294559797370881                                           Muti_79
# ...                    ...                                               ...
# 31816            467645507                           T.C. İçişleri Bakanlığı
# 31817  1246020601996816385                                            tuncay
# 31818            601097854                          GMG Kastamonuspor Kulübü
# 31819            356064164                                           Show TV
# 31820   995985841368510464                                             Hocca
#
#       user_screen_name                user_location  \
# 0       grslsntlarogrt                       Mardin
# 1        adnantoprak46                      Türkiye
# 2            oykunejla                        izmir
# 3        yalaaaaannnnn
# 4              muti_79              Ankara, Türkiye
# ...                ...                          ...
# 31816      tc_icisleri                      Türkiye
# 31817      tuncayyilmz               Gebze, Türkiye
# 31818   gmgkastamonusk                    Kastamonu
# 31819           showtv            İstanbul, Türkiye
# 31820   hocca_official  Manhattan, NY (Wall Street)
#
#                                         user_description  \
# 0                            Görsel Sanatlar Öğretmeni 🎨
# 1
# 2      Önce insan...\nAnne❤\nHemşire❤\nHayvansever❤\n...
# 3                           Hüloğcular lütfen uzan durun
# 4
# ...                                                  ...
# 31816  T.C. İçişleri Bakanlığı Resmi Twitter Sayfası,...
# 31817                                  her şeyimi buldum
# 31818  GMG Kastamonuspor Kulübü Resmi Twitter Hesabı ...
# 31819  Show TV Resmi Twitter Profili https://t.co/d0g...
# 31820  MİLYONERLER KULÜBÜ\nRobotlara fısıldayan ADAM😎...
#
#        user_followers_count  user_friends_count  description_len  is_verified  \
# 0                      2527                2609               27            0
# 1                      7527                6755                0            0
# 2                      8819                8591              159            0
# 3                       284                1352               28            0
# 4                      3866                3937                0            0
# ...                     ...                 ...              ...          ...
# 31816               2408670                  29              119            1
# 31817                  8191                8183               17            0
# 31818                  9323                  20               82            0
# 31819               1355456                 111              101            1
# 31820                 67674                 169              114            0
#
#        followers_to_all_ratio
# 0                    0.492017
# 1                    0.527027
# 2                    0.506548
# 3                    0.173594
# 4                    0.495450
# ...                       ...
# 31816                0.999988
# 31817                0.500244
# 31818                0.997859
# 31819                0.999918
# 31820                0.997509
#
# [31821 rows x 10 columns]

# %% [markdown]
# ### 1.2.2. Get Tweet Info of Users in user_profiles.jsons.gz

# %% [markdown]
# #### 1.2.2.1. Check ratio of retweets to all tweets

# %%
def get_retweet_tweet_ratio(line):
    number_retweets = 0
    number_original_tweets = 0

    for tweet in line['tweets']:
        try:
            tweet['retweeted_status']
            number_retweets += 1
                
        except:
            number_original_tweets += 1
            
    total_tweets = number_retweets + number_original_tweets
    
    if total_tweets == 0:
        retweet_total_ratio = None
    else:
        retweet_total_ratio = number_retweets/(total_tweets)
    
    return retweet_total_ratio

# %% [markdown]
# #### 1.2.2.2. Check median number of favorites

# %%
def get_median_number_favorites(line):
    num_median_favorites = np.median([tweet['favorite_count'] for tweet in line['tweets']])

    return num_median_favorites

# %% [markdown]
# ### 1.2.3. Collect data using the functions above and transform into a Pandas DataFrame

# %%
dfBotTweets = {'user_id':[],
               'retweet_total_ratio':[],
               'num_median_favorites':[]}

i = 0

with gzip.open(f"/content/drive/MyDrive/CS412-Project-Files/user_tweets.jsons.gz", "rb") as f:
    for line in f:

        line = json.loads(line)

        user_id = line['user_id']
        dfBotTweets['user_id'].append(user_id)
        
        retweet_total_ratio = get_retweet_tweet_ratio(line)
        dfBotTweets['retweet_total_ratio'].append(retweet_total_ratio)
        
        num_median_favorites = get_median_number_favorites(line)
        dfBotTweets['num_median_favorites'].append(num_median_favorites)

        

        i += 1
        
        if i % 10000 == 0:
            print(i)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 10000
# 20000

# %%
dfBotTweets = pd.DataFrame(dfBotTweets)
dfBotTweets
# Out:
#                    user_id  retweet_total_ratio  num_median_favorites
# 0               1044821071             0.090000                  57.0
# 1               1086355147             0.172973                  10.0
# 2                205625453             0.000000                   9.0
# 3      1382717948092157953             0.356784                   0.0
# 4      1302055645307375618             0.646154                   0.0
# ...                    ...                  ...                   ...
# 29901           1865050056             0.890411                   0.0
# 29902  1336329028324577281             0.783920                   0.0
# 29903  1214219054329675777             0.970588                   0.0
# 29904            310390437             0.875000                   0.0
# 29905  1284767643459899392             0.949749                   0.0
#
# [29906 rows x 3 columns]

# %% [markdown]
# ### 1.2.3. Merge dfBot and dfBotTweets

# %%
dfBotAll = dfBot.merge(dfBotTweets,
                       how='left')

dfBotAll[['retweet_total_ratio', 'num_median_favorites']] = dfBotAll[['retweet_total_ratio', 'num_median_favorites']].fillna(0)

dfBotAll
# Out:
#                    user_id                                         user_name  \
# 0      1195008426784493571                                      Mesut Demir🎨
# 1       912738858437050369                                       AdnanToprak
# 2               2490178497  Nejla ÖNÇIRAK😷 bilgin yoksa , fikrin de olmasın👍
# 3                161774611                             Tek Kişilik Muhalefet
# 4      1349294559797370881                                           Muti_79
# ...                    ...                                               ...
# 31816            467645507                           T.C. İçişleri Bakanlığı
# 31817  1246020601996816385                                            tuncay
# 31818            601097854                          GMG Kastamonuspor Kulübü
# 31819            356064164                                           Show TV
# 31820   995985841368510464                                             Hocca
#
#       user_screen_name                user_location  \
# 0       grslsntlarogrt                       Mardin
# 1        adnantoprak46                      Türkiye
# 2            oykunejla                        izmir
# 3        yalaaaaannnnn
# 4              muti_79              Ankara, Türkiye
# ...                ...                          ...
# 31816      tc_icisleri                      Türkiye
# 31817      tuncayyilmz               Gebze, Türkiye
# 31818   gmgkastamonusk                    Kastamonu
# 31819           showtv            İstanbul, Türkiye
# 31820   hocca_official  Manhattan, NY (Wall Street)
#
#                                         user_description  \
# 0                            Görsel Sanatlar Öğretmeni 🎨
# 1
# 2      Önce insan...\nAnne❤\nHemşire❤\nHayvansever❤\n...
# 3                           Hüloğcular lütfen uzan durun
# 4
# ...                                                  ...
# 31816  T.C. İçişleri Bakanlığı Resmi Twitter Sayfası,...
# 31817                                  her şeyimi buldum
# 31818  GMG Kastamonuspor Kulübü Resmi Twitter Hesabı ...
# 31819  Show TV Resmi Twitter Profili https://t.co/d0g...
# 31820  MİLYONERLER KULÜBÜ\nRobotlara fısıldayan ADAM😎...
#
#        user_followers_count  user_friends_count  description_len  is_verified  \
# 0                      2527                2609               27            0
# 1                      7527                6755                0            0
# 2                      8819                8591              159            0
# 3                       284                1352               28            0
# 4                      3866                3937                0            0
# ...                     ...                 ...              ...          ...
# 31816               2408670                  29              119            1
# 31817                  8191                8183               17            0
# 31818                  9323                  20               82            0
# 31819               1355456                 111              101            1
# 31820                 67674                 169              114            0
#
#        followers_to_all_ratio  retweet_total_ratio  num_median_favorites
# 0                    0.492017                0.060                   1.0
# 1                    0.527027                0.200                 107.0
# 2                    0.506548                0.230                   1.0
# 3                    0.173594                0.000                   0.0
# 4                    0.495450                1.000                   0.0
# ...                       ...                  ...                   ...
# 31816                0.999988                0.735                   0.0
# 31817                0.500244                0.020                   1.0
# 31818                0.997859                0.000                  24.0
# 31819                0.999918                0.000                  76.5
# 31820                0.997509                0.005                  41.0
#
# [31821 rows x 12 columns]

# %% [markdown]
# # 2. TRAIN MODEL

# %% [markdown]
# ## 2.1. Political Tweet Prediction

# %% [markdown]
# ### 2.1.1. Merge dfPolitical data with labels

# %%
dfPoliticalAll_train = dfPolitical.merge(trainingTweetDf,
                                         on='tweet_id')

dfPoliticalAll_train.head()
# Out:
#               tweet_id  is_retweet retweeted_username  \
# 0  1422716317359083524           1     ekrem_imamoglu
# 1  1443994036847710225           1       habermujdeli
# 2  1448987280740438016           1        ibrahim_yka
# 3  1436370160731017219           1             feoist
# 4  1425552306104307724           1            akparti
#
#                                                 text  num_mentions  \
# 0  RT @ekrem_imamoglu: Alarmı kurduk! Sanmayın ki...             1
# 1  RT @HaberMujdeli: İSPARK niye zarar etsin diye...             1
# 2  RT @ibrahim_yka: Hüsniye Erdoğan Mini HDP 9  8...             1
# 3  RT @feoist: @drfahrettinkoca Allah senin çocuk...             2
# 4  RT @Akparti: Cumhurbaşkanımız @RTErdogan: Teme...             2
#
#    num_hashtags  num_retweets  num_favorites              user_id  \
# 0             1          3596              0  1151776206427234304
# 1             0          1252              0  1029972980707860485
# 2             0            36              0  1381515272406900738
# 3             0             1              0  1361792750375628800
# 4             1           543              0   763812418724200448
#
#   user_screen_name                                   user_description  \
# 0        oykulovic                            Bu terslikte bi iş var🦥
# 1       erefdnmez6  Reisinin emrinde, Ak parti gönüllüsü, Vatanın,...
# 2     nurierdemli1
# 3   ismail93613027
# 4   ebru_gursultur
#
#    num_political_entities  total_interactions isPolitical
# 0                       1                3596          No
# 1                       0                1252         Yes
# 2                       0                  36         Yes
# 3                       1                   1          No
# 4                       2                 543         Yes

# %% [markdown]
# ### 2.1.2. Separate X and y values
# We only use 3 features here to create a baseline model. However, it is not enough to get good results.

# %%
X = dfPoliticalAll_train[['total_interactions','num_political_entities','num_retweets','num_hashtags','num_mentions']]
y = dfPoliticalAll_train['isPolitical'].apply(lambda x: 1 if x=='Yes' else 0)

# %% [markdown]
# ### 2.1.3. Train - validation split

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# ### 2.1.4. Train the model
#
# Here, you may use different models such as neural networks, XGBoost, AdaBoost, RandomForest, Linear Regression, Logistic Regression etc. to see which model does the best. Also, you can use grid_search_cv() or a basic for loop to optimize the hyperparameters of your model.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error

# create an instance
dtc_political = DecisionTreeClassifier()

# fit your model
dtc_political.fit(X_train, y_train)

# make predictions
preds = dtc_political.predict(X_valid)

# evaluate on validation set
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)
mse = mean_squared_error(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# MSE: 0.26
#  Accuracy Score: 0.74
#  Confusion Matrix:
#  [[244  42]
#  [114 200]]

# %%
##KNN MODEL FOR POLITICAL TWEET

from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
mean_squared_error_list = []

RangeForK = np.arange(1, 15)


for k in RangeForK:
  # New Model For K
  KNN = KNeighborsRegressor(k, metric="euclidean")

  KNN.fit(X_train, y_train)
  
  y_pred = KNN.predict(X_valid)
 
  mse = mean_squared_error(y_valid, preds)
  mean_squared_error_list.append(mse)

plt.figure(figsize=(16, 8))  
plt.plot(RangeForK, mean_squared_error_list, color='black', linestyle='dashed', marker='o',  
         markerfacecolor='red', markersize=12)
plt.title('MSE FOR the Validation')  
plt.xlabel('K')  
plt.ylabel('MSE')
plt.xticks(RangeForK)
plt.grid()
plt.show()

# %%
#### Regression Three

from sklearn.tree import DecisionTreeRegressor
regression_tree=DecisionTreeRegressor(max_depth=7)
regression_tree.fit(X_train, y_train)
y_Prediction_Train = regression_tree.predict(X_train)

print ("MSE for train value"  ,mean_squared_error(y_train, y_Prediction_Train))
# Out:
# MSE for train value 0.12698031353878392

# %%
#ADABOOST

from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import AdaBoostRegressor
from sklearn import metrics

X_train_ada, X_valid_ada, y_train_ada, y_valid_ada = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
AdaClassifier = AdaBoostClassifier()
AdaClassifier.fit(X_train_ada, y_train_ada)
y_expected = y_valid_ada
y_predicted = AdaClassifier.predict(X_valid_ada)

# %%
print ("MSE for train value"  ,mean_squared_error(y_expected, y_predicted))
# Out:
# MSE for train value 0.21

# %%
AdaReg = AdaBoostRegressor()
AdaReg.fit(X_train_ada, y_train_ada)
# Out:
# AdaBoostRegressor()

# %%
expected_y2  = y_valid_ada
predicted_y2 = AdaReg.predict(X_valid_ada)

# %%
print("Mean Square Error", metrics.mean_squared_error(expected_y2, predicted_y2))
# Out:
# Mean Square Error 0.1680904403218373

# %% [markdown]
# ## 2.2. Bot Detection

# %% [markdown]
# ### 2.2.1. Merge dfBotAll data with labels

# %%
dfBotAll.user_screen_name = dfBotAll.user_screen_name.str.lower()

# %%
dfBotAll_train = dfBotAll.merge(trainingUserDf,
                               left_on='user_screen_name',
                               right_on='screen_name')

dfBotAll_train
# Out:
#                   user_id                    user_name user_screen_name  \
# 0     1301168604667355142                    Doğabilim     dogabilimorg
# 1               628886610               Esra Nur ÖZDEN  esranurmuratozd
# 2               547532939                  Kübra Şakır        kubussskr
# 3               946826934             Gökhan İZGİ 🇹🇷🇦🇿     gokhanizgi34
# 4      802201284833067009                   Oral Orhon    orhonoral1975
# ...                   ...                          ...              ...
# 2994  1338444706204835840                  laito proof         vtaeskit
# 2995            323513738                      Ezgobar        shaammone
# 2996  1451270540669378572                   Havva Sert      havvasert19
# 2997  1354034188815654912                         airi         airilynx
# 2998            326232761  Türkiye Satranç Federasyonu     turkishchess
#
#             user_location                                   user_description  \
# 0                          Gerçek Bilginin Işığında!\nYayınlarımıza ulaşm...
# 1                  Turkey  📍Güzeller güzeli 4 melek annesi\n📍Ak Parti Ank...
# 2              iskenderun  'Allah'tan başka uğruna koştuğun hiçbir şey dü...
# 3       İstanbul, Türkiye  📰 Gazeteci - Yazar  | 📘 S.O.S.YAL MEDYA kitabı...
# 4       İstanbul, Türkiye  Holigan değil, sağlıklı ve Atatürkçü bir BEŞİK...
# ...                   ...                                                ...
# 2994  eu ar55 childe main                namjoon yalvaririm telefonlarimi ac
# 2995                İzmir                                    humanoid 🏉 🏳️‍🌈
# 2996
# 2997        ♡🧷she/her 18   #mitski ; i start the day high and it ends so ...
# 2998               Ankara  Türkiye Satranç Federasyonu Resmi Twitter Hesa...
#
#       user_followers_count  user_friends_count  description_len  is_verified  \
# 0                      803                  93              109            0
# 1                     1962                1650              134            0
# 2                      531                 137               86            0
# 3                    42188               33979              146            0
# 4                     3988                4995               78            0
# ...                    ...                 ...              ...          ...
# 2994                   270                 673               35            0
# 2995                   521                 330               15            0
# 2996                   155                 199                0            0
# 2997                   712                 585               82            0
# 2998                 12540                 540              100            0
#
#       followers_to_all_ratio  retweet_total_ratio  num_median_favorites  \
# 0                   0.896205             0.030000                   1.0
# 1                   0.543189             0.985000                   0.0
# 2                   0.794910             0.523560                   0.0
# 3                   0.553888             0.320000                   1.0
# 4                   0.443950             0.393939                   0.0
# ...                      ...                  ...                   ...
# 2994                0.286320             0.050000                   1.0
# 2995                0.612221             0.025000                   1.0
# 2996                0.437853             0.835052                   0.0
# 2997                0.548959             0.120000                   1.0
# 2998                0.958716             0.175000                  17.0
#
#           screen_name isBot
# 0        dogabilimorg    No
# 1     esranurmuratozd    No
# 2           kubussskr    No
# 3        gokhanizgi34    No
# 4       orhonoral1975    No
# ...               ...   ...
# 2994         vtaeskit    No
# 2995        shaammone    No
# 2996      havvasert19    No
# 2997         airilynx    No
# 2998     turkishchess    No
#
# [2999 rows x 14 columns]

# %%
trainingUserDf.isBot.value_counts()
# Out:
# No          2363
# Yes          401
# Not sure     236
# Name: isBot, dtype: int64

# %% [markdown]
# ### 2.2.2. Separate X and y values
# We use only 4 features here to create a baseline model. However, it is not enough to get good results.

# %%
X = dfBotAll_train[['user_followers_count', 'followers_to_all_ratio', 'user_friends_count', 'description_len','is_verified','num_median_favorites']]
y = dfBotAll_train.isBot.apply(lambda x: 1 if x=='Yes' else 0)

# %% [markdown]
# ### 2.2.3. Train-test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# ### 2.2.4. Train the model

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error

# create an instance
dtc_bot = DecisionTreeClassifier()

# fit your model
dtc_bot.fit(X_train, y_train)

# make predictions
preds = dtc_bot.predict(X_valid)

# evaluate on validation set
acc_score = accuracy_score(y_valid, preds)
confusion = confusion_matrix(y_valid, preds)

print("MSE:", mse, "\n",
      "Accuracy Score:", acc_score, "\n",
      "Confusion Matrix:", "\n", confusion)
# Out:
# MSE: 0.26
#  Accuracy Score: 0.765
#  Confusion Matrix:
#  [[443  62]
#  [ 79  16]]

# %%
###KNN

##KNN MODEL FOR BOT

from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
mean_squared_error_list = []

RangeForK = np.arange(1, 15)


for k in RangeForK:
  # New Model For K
  KNN = KNeighborsRegressor(k, metric="euclidean")

  KNN.fit(X_train, y_train)
  
  y_pred = KNN.predict(X_valid)
 
  mse = mean_squared_error(y_valid, preds)
  mean_squared_error_list.append(mse)

plt.figure(figsize=(16, 8))  
plt.plot(RangeForK, mean_squared_error_list, color='black', linestyle='dashed', marker='o',  
         markerfacecolor='red', markersize=12)
plt.title('MSE FOR the Validation')  
plt.xlabel('K')  
plt.ylabel('MSE')
plt.xticks(RangeForK)
plt.grid()
plt.show()

# %%
#### Regression Three

from sklearn.tree import DecisionTreeRegressor
regression_tree=DecisionTreeRegressor(max_depth=7)
regression_tree.fit(X_train, y_train)
y_Prediction_Train = regression_tree.predict(X_train)

print ("MSE for train value"  ,mean_squared_error(y_train, y_Prediction_Train))
# Out:
# MSE for train value 0.09051717605977307

# %%
#ADABOOST

# %%
X_train_ada, X_valid_ada, y_train_ada, y_valid_ada = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
AdaClassifier = AdaBoostClassifier()
AdaClassifier.fit(X_train_ada, y_train_ada)
y_expected  = y_valid_ada
y_predicted = AdaClassifier.predict(X_valid_ada)

# %%
print ("MSE for train value"  ,mean_squared_error(y_expected, y_predicted))
# Out:
# MSE for train value 0.15666666666666668

# %%
AdaReg = AdaBoostRegressor()
AdaReg.fit(X_train_ada, y_train_ada)
y_expected2 = y_valid_ada
y_predicted2= AdaReg.predict(X_valid_ada)
print("Mean square error",metrics.mean_squared_error(y_expected2, y_predicted2))
# Out:
# Mean square error 0.1321139005264818

# %% [markdown]
# # 3. MAKE PREDICTIONS
#
# Here, you will make predictions with the models that you have trained above.

# %% [markdown]
# ## 3.1. Predictions for Tweets (Political or Not)

# %%
# read the evaluation file as follows
evaluationTweetDf = pd.read_csv('evaluation-round2-tweet.csv', dtype={0: str}, header=None, names=['tweet_id'])
evaluationTweetDf = evaluationTweetDf.dropna()
evaluationTweetDf

# merge it with the political dataframe so that you can use the make predictions based on the variables
dfPolitical_test = dfPolitical.merge(evaluationTweetDf)

# define X as we did above in section (2.x.2. Separate X and y values)
X = dfPoliticalAll_train[['total_interactions','num_political_entities','num_retweets','num_hashtags','num_mentions']]

# make predictions based on these variables
predictions_political = dtc_political.predict(X)

# %% [markdown]
# ### This part is important! We expect you to return your predictions in the following format:

# %%
evaluationUserDf = pd.read_csv('evaluation-round2-user.csv', dtype={0: str}, header=None, names=['user_screen_name'])
evaluationUserDf = evaluationUserDf.dropna()

# merge it with the political dataframe so that you can use the make predictions based on the variables
dfBot_test = dfBotAll.merge(evaluationUserDf)

# define X as we did above in section (2.x.2. Separate X and y values)
X = dfBot_test[['user_followers_count', 'followers_to_all_ratio', 'user_friends_count', 'description_len','is_verified','num_median_favorites']]

# make predictions based on these variables
predictions_bot = dtc_bot.predict(X)

# %%
modelPredUser = dict([(x,float(y)) for x,y in zip([*dfBot_test.user_screen_name], predictions_bot)])
modelPredUser
# Out:
# {'adnantoprak46': 0.0,
#  'oykunejla': 0.0,
#  'ay3613': 0.0,
#  'hazanguzel': 0.0,
#  'sabirsiztr': 0.0,
#  'alonedrummer': 0.0,
#  'doktoramaaktor': 0.0,
#  'canimmbenimm3': 0.0,
#  'muneccimsimge': 1.0,
#  'gsbgenclikspor': 0.0,
#  'koramzeynep': 0.0,
#  'rabosscy': 0.0,
#  'aykut190720': 0.0,
#  'shadowoflower': 0.0,
#  'adler16392917': 0.0,
#  'alioztoprak06': 0.0,
#  'taylankumelii': 0.0,
#  'ozk_emrullah': 0.0,
#  'emineemiir': 0.0,
#  'rsrsrs97': 0.0,
#  'herseyeloji': 0.0,
#  'eceemsoysal': 0.0,
#  'prfbaris': 0.0,
#  'emell_zaim': 0.0,
#  'seminanurrk': 0.0,
#  'viennabjk93': 1.0,
#  'neogaymyback': 0.0,
#  'theinformavore': 0.0,
#  'ahmetin93': 0.0,
#  'akrepkral1507': 0.0,
#  'dutal28': 1.0,
#  'veckatimest': 0.0,
#  'torbacisso': 0.0,
#  'whiplashgirl_': 0.0,
#  'senihadeyin': 1.0,
#  'meloreco_recmel': 0.0,
#  'limon99': 0.0,
#  'bagcebariscan': 1.0,
#  'dafemfairy': 0.0,
#  'hadibak': 0.0,
#  'evk87026945': 0.0,
#  'aytacvehbi': 1.0,
#  'tasduzgun': 0.0,
#  'f_pandaq': 0.0,
#  'bilalonline65': 0.0,
#  'slmgkck': 0.0,
#  'cenkeroglu_1905': 1.0,
#  'dcnp01': 0.0,
#  'garciagala_': 0.0,
#  'gokmenozcan': 0.0,
#  'lovewithciv': 0.0,
#  'sakinolsedosss': 0.0,
#  'sansursuzprof': 0.0,
#  'lollabunnny': 0.0,
#  'denksizdishekim': 0.0,
#  'damla967591581': 0.0,
#  'reelhumanist': 0.0,
#  'hepibiri': 0.0,
#  'opekgurler': 0.0,
#  'onurduruu': 0.0,
#  'yusufck000': 0.0,
#  'limondilimi': 0.0,
#  'jumpituupp': 0.0,
#  'gokmaviilim': 0.0,
#  'nalan_ibo': 0.0,
#  'abdullah_adnr': 1.0,
#  'halil_taskran': 0.0,
#  '0pinar7': 0.0,
#  'grligurel': 0.0,
#  'bakbipro1': 0.0,
#  'ziya1467': 0.0,
#  'uguralzu': 1.0,
#  'matsumo45735308': 1.0,
#  'zfr58': 0.0,
#  'seda_incekara': 0.0,
#  'azonceolducom': 0.0,
#  'saglikcisin': 0.0,
#  'sibilcetinkaya': 0.0,
#  'yesorrayt': 0.0,
#  'tcddemiryollari': 0.0,
#  'ercancoskun_': 0.0,
#  'senveask35': 0.0,
#  'fatma_aytac': 1.0,
#  'alikurt_0032': 0.0,
#  'ipek52644359': 0.0,
#  'imadein94': 0.0,
#  'soypatopato': 0.0,
#  'iyigenclikksk': 0.0,
#  'hamzamusaoglu': 0.0,
#  'turkcesondakika': 0.0,
#  'gamzeyildizturk': 0.0,
#  'jeonysus97_': 0.0,
#  'mississippi_yy': 0.0,
#  'tekinbingolchp': 0.0,
#  'nickemel': 0.0,
#  'anestezitk_': 0.0,
#  'ibrahimyrdkl': 0.0,
#  '_dipsizkuyu': 0.0,
#  'fundabezos': 0.0,
#  'mediolanumm': 0.0,
#  'medtheslayer': 0.0,
#  'altaykurtoglu_': 0.0,
#  'erdiaydoan77': 0.0,
#  'karakecili26': 0.0,
#  'uygar_cagdas': 0.0,
#  'onurtorunogluu': 1.0,
#  'fuatturgudresmi': 0.0,
#  'yasinkarakas01': 0.0,
#  'isimbulamadim_2': 0.0,
#  'trndvcturan': 0.0,
#  'tuncgulusan': 0.0,
#  'apoosahinnn': 0.0,
#  'melosfacts': 0.0,
#  'mimarc07': 1.0,
#  'poncikbruiser': 0.0,
#  'osmannkahya': 0.0,
#  'purenyo': 0.0,
#  'salihsib': 0.0,
#  'yadaglsn': 1.0,
#  'dodo_dodoissstt': 1.0,
#  'lena45308196': 1.0,
#  'bozbozzz35': 0.0,
#  'avmbalci': 0.0,
#  'muftuoglumhmt': 0.0,
#  'k_twitir': 0.0,
#  'kadir_tarhann': 0.0,
#  'cagdasbayraktar': 0.0,
#  'nihatsezerzb': 0.0,
#  'akkahramanmaras': 0.0,
#  'erkekdiilimben': 0.0,
#  'zahir_soganda': 0.0,
#  'cundi_1453': 0.0,
#  'scoutkartali': 0.0,
#  'helinakbykk': 0.0,
#  'eesmacndr58': 0.0,
#  'unsuzyazarrr': 0.0,
#  'aksungur__': 0.0,
#  'halilhakan54': 0.0,
#  'eslmkkk': 0.0,
#  'gkhanurun7': 0.0,
#  'tubaguneybaz': 0.0,
#  '19ahmetemin03': 0.0,
#  'emirdokumm': 0.0,
#  'aydnselcen': 0.0,
#  'ayhanbarut01': 0.0,
#  'erencn_': 1.0,
#  'ozgetercn': 0.0,
#  'qbasaran': 0.0,
#  'centreamicale': 0.0,
#  'omercbkc': 1.0,
#  'rehan44213': 0.0,
#  'rbasaran1905': 0.0,
#  '6srplb1': 0.0,
#  'ziyaylds': 0.0,
#  'cbaslevent': 0.0,
#  '63meralkaya': 0.0,
#  'ozan__akkaya': 1.0,
#  'bilalkizmaz': 0.0,
#  'ufomuyo': 0.0,
#  'babussokutan': 0.0,
#  'evcihayrettin': 0.0,
#  'bucakism': 0.0,
#  'tahirduymaz': 0.0,
#  'emirpektass52': 0.0,
#  'llisans': 0.0,
#  'arslanates': 0.0,
#  'yasar_belimm': 0.0,
#  'erenaktan': 0.0,
#  'emre_eren0': 0.0,
#  'nuriatasoy': 1.0,
#  'ukrintr': 0.0,
#  'cemreetopall': 0.0,
#  'zeynu___eb': 1.0,
#  'nedensizsor': 0.0,
#  'sencerkiris': 1.0,
#  'beyzaatas': 0.0,
#  'dingilsavar': 0.0,
#  'aahmttprk': 0.0,
#  'zulfikaraltay': 0.0,
#  'kizillsakal': 0.0,
#  'h_ibrahimselcuk': 0.0,
#  'sinan16': 0.0,
#  'berf2nn': 1.0,
#  'bdrhn90398474': 0.0,
#  '_feroderler': 0.0,
#  'halilnarinn': 1.0,
#  'rusenpress': 0.0,
#  'ramazan': 0.0,
#  'caglalaylalayp': 0.0,
#  'muhammedibr1881': 0.0,
#  'sabrina70708979': 0.0,
#  'berkaktolun': 0.0,
#  'clavistuus': 0.0,
#  'atama44': 0.0,
#  'ismaildemirssb': 0.0,
#  'cs_nba': 0.0,
#  'krtl_eda': 0.0,
#  'snlaktn': 0.0,
#  'fikretba11': 0.0,
#  'aygibisen': 0.0,
#  'sb20172020': 0.0,
#  'todesarten': 0.0,
#  'yaseminbender': 0.0,
#  'nothing19233291': 0.0,
#  'erkant01': 0.0,
#  'sunanaberya': 1.0,
#  'fbciyim': 0.0,
#  'metinmete': 0.0,
#  'ferhatjk_': 0.0,
#  'blackkcrab': 0.0,
#  'agdaggulsanem': 0.0,
#  'byzaozgenn': 0.0,
#  'waterr_': 0.0,
#  'betussssssss99': 0.0,
#  'celalkose66': 0.0,
#  'tugba_cpr': 0.0,
#  'cpr_cpr': 0.0,
#  '_muratfiratt': 1.0,
#  'brightbizedever': 1.0,
#  'besimtokerr': 0.0,
#  'turkemblondon': 0.0,
#  'koinbulteni': 0.0,
#  'istencigulseren': 0.0,
#  'ofamerikanmutfa': 0.0,
#  'cardicrk': 0.0,
#  'sade_ninja': 0.0,
#  'ldtasdelen': 0.0,
#  'utkuernestososa': 0.0,
#  'nazca_k': 0.0,
#  '61_tunca': 0.0,
#  'wiassen': 0.0,
#  'yusufyazici_tr': 0.0,
#  'aycasarikamisli': 0.0,
#  'tlyayt5': 0.0,
#  'cnbatu0': 0.0,
#  'f1seyircisi': 0.0,
#  'ercanpaksoy2': 0.0,
#  'zebrefn': 0.0,
#  'fidaneus': 0.0,
#  'criminalcause3': 0.0,
#  'pozitifhisler': 1.0,
#  'konushma': 0.0,
#  'kiremitciev': 0.0,
#  'onlyyrain': 0.0,
#  'ufukkurt97': 0.0,
#  'niluferyetim': 0.0,
#  'leventhangul': 0.0,
#  'mentraxmus': 0.0,
#  'mrbnretro': 0.0,
#  'eliftrylaz1': 0.0,
#  'direnselimoglu': 0.0,
#  'meliisgnveer': 0.0,
#  'carslberk': 0.0,
#  '2tekilruhadam': 0.0,
#  'berfinzengiin': 0.0,
#  'yucekimtae': 1.0,
#  'ehasturk': 0.0,
#  'borsaa': 0.0,
#  '_kaankoc_': 0.0,
#  'tinycherrykiss': 0.0,
#  'emin_pekmezci': 0.0,
#  'meveyla': 0.0,
#  'koraymadrid': 1.0,
#  'patriotbaskan': 1.0,
#  'zehir_online': 0.0,
#  'furkanclllkk': 1.0,
#  'mrtsmsk8': 1.0,
#  'akifdogann': 0.0,
#  'arslan5568': 0.0,
#  'dsvdaa': 0.0,
#  'agahpamukov': 0.0,
#  'erkan1359': 0.0,
#  'jennie_world0': 1.0,
#  'bayrambeki': 0.0,
#  'irmakokullari': 0.0,
#  'fthdvn': 1.0,
#  'mavidusler_s': 0.0,
#  'arven_ar': 0.0,
#  'mrxxx2x': 0.0,
#  'fatihatay2516': 0.0,
#  'ayseeakturk': 0.0,
#  'fthsahiner': 0.0,
#  'seydaabek': 0.0,
#  'senayurdaoz': 0.0,
#  'besgyehayir': 0.0,
#  'onsuzluktan': 1.0,
#  'saglikcitukendi': 0.0,
#  'nelkioloji': 0.0,
#  's_selcuk_1881': 0.0,
#  'lettyortizm': 1.0,
#  'metalicry': 1.0,
#  'gntknb': 0.0,
#  'mavikar71': 0.0,
#  'bzkrtisrafil72': 0.0,
#  'niiiiddddaaaa': 0.0,
#  'quzulqurtp': 1.0,
#  'mhptbmmgrubu': 0.0,
#  'hasantoktastr': 0.0,
#  'lhdxrtr2sulpd6n': 1.0,
#  'yaseminmet2': 0.0,
#  'svlah_2506': 0.0,
#  'harbiyeli_murat': 0.0,
#  'polatmursel': 0.0,
#  'drtasdogan': 0.0,
#  'yilmazuk': 0.0,
#  '1sinurr': 0.0,
#  'htulinengin': 1.0,
#  'sereinoir': 0.0,
#  'alpc1905': 0.0,
#  'izmironder': 0.0,
#  '___zehraa': 0.0,
#  'euphemia01': 0.0,
#  'yavuzsyildiz': 0.0,
#  'ceyrek_porsiyon': 0.0,
#  'ankaral20': 0.0,
#  'ipekshabit': 0.0,
#  'dilara__dg': 1.0,
#  'muratrecepalp': 0.0,
#  'vangoghvii': 0.0,
#  'eytmuratmka': 0.0,
#  'neslisahgonte': 0.0,
#  'esinorhan26': 1.0,
#  'hsyn27921058': 0.0,
#  'menetyasar': 0.0,
#  'toplumbilmci': 0.0,
#  'akpartisogutlu': 0.0,
#  'ncg1905': 0.0,
#  'hyuga_land': 0.0,
#  'osmanka94399637': 0.0,
#  'miraclslk': 0.0,
#  'enveryalcin59': 0.0,
#  'aycanlve': 0.0,
#  'aranyksel1': 0.0,
#  'akittv': 0.0,
#  'dunyabirkitaptr': 0.0,
#  'popedeniz': 0.0,
#  'bozorize': 0.0,
#  'lengluichicks': 0.0,
#  'reiscisezo': 0.0,
#  'mehmettft9': 0.0,
#  'ankarali330': 0.0,
#  'seyitcad1': 0.0,
#  'kenandemiray13': 0.0,
#  'adamyaziyoryaa': 0.0,
#  'gsb_mersingm': 0.0,
#  'cetinkacmaz6': 0.0,
#  'lahma_nam_cun7': 0.0,
#  'nolursusunbi': 0.0,
#  'akeskisehir26': 0.0,
#  'fenerist1923': 0.0,
#  'incikosal': 0.0,
#  'the_senator34': 0.0,
#  'sunb0yhyuck': 0.0,
#  'prmdk112prm1': 0.0,
#  'kkyaveri': 0.0,
#  'senna_1233': 0.0,
#  'melike24747': 0.0,
#  'lovelytrabzon': 0.0,
#  'mstftkdgn06': 0.0,
#  'iserbest102': 0.0,
#  'silent39972395': 0.0,
#  '_underinfluence': 0.0,
#  'cihanatli': 0.0,
#  'by_brutal': 0.0,
#  '35bahadir': 0.0,
#  'melinastro': 0.0,
#  'kopruluahmet94': 0.0,
#  'recepates1965': 1.0,
#  'cadisko1907': 1.0,
#  'uraalperenpusat': 0.0,
#  'merve84337491': 0.0,
#  'lilithyane': 0.0,
#  'sehunenayisi': 1.0,
#  '89_meliss': 0.0,
#  'nuremirgil': 0.0,
#  'sewelankoana': 0.0,
#  'ededdd5': 1.0,
#  'hisseanaliztr': 0.0,
#  'shot_jane': 0.0,
#  'ayhanarslan686': 0.0,
#  'gunes_gazetesi': 0.0,
#  'ofegin': 0.0,
#  'mizci65': 1.0,
#  'aymsorryla': 0.0,
#  'gucok': 0.0,
#  'zelalyalcin': 1.0,
#  'sryfth': 0.0,
#  'lkernver3': 0.0,
#  'nilgun_istanbul': 0.0,
#  'baytekinhalit': 0.0,
#  'etkinlikhesab13': 0.0,
#  'cilek000': 0.0,
#  'krsiklra': 0.0,
#  'wassertropfenn': 1.0,
#  'salihanurtac': 0.0,
#  'blc_erhan': 1.0,
#  'av_mdmustafa': 0.0,
#  'emre03ozturk': 0.0,
#  'nurgencccc': 0.0,
#  'bucaksertac': 0.0,
#  'rzgar23311055': 0.0,
#  'timurmelik33': 0.0,
#  'birolbirsen': 0.0,
#  'erenginer': 0.0,
#  'betonkemalist4': 0.0,
#  'lilo7imfine': 0.0,
#  'kayakay07768716': 0.0,
#  'havadurumu5com': 0.0,
#  'ak_ferhatpasa34': 0.0,
#  'alp15940870': 1.0,
#  'yildirayc_1907': 0.0,
#  'ozcetinnilay': 1.0,
#  'esourlkaya3536': 0.0,
#  'jonsnow19691570': 0.0,
#  'ftmshn0': 0.0,
#  'kurban311': 1.0,
#  'silacalis_': 0.0,
#  'polatizmir35': 1.0,
#  'birol75481453': 0.0,
#  'gallavichsbae': 0.0,
#  'hweseungum': 0.0,
#  'anamur_2023': 0.0,
#  'therearetumblr': 0.0,
#  'artiks8': 0.0,
#  'omerkilic51': 1.0,
#  'bormusav': 0.0,
#  'omermer41962014': 0.0,
#  'ozbekfigen1': 0.0,
#  'ayuceak': 0.0,
#  'serdart19523470': 0.0,
#  'ali_guvenbas': 0.0,
#  'atlasam': 0.0,
#  'hakan38494543': 0.0,
#  'kerimyildiz21': 0.0,
#  'akaraismailoglu': 0.0,
#  'umutsuzumbeybi': 1.0,
#  'astromedya': 0.0,
#  'karahuseyinler': 0.0,
#  'ercancon': 1.0,
#  'yeshuayosefson': 0.0,
#  'arjinnn_73botan': 1.0,
#  'baldwinerrw': 0.0,
#  'mesut_35_mka': 0.0,
#  'vphakespeare': 0.0,
#  'jouskaw': 0.0,
#  'oguzozbey2': 0.0,
#  'zentinytomoon': 0.0,
#  'huanghyck': 0.0,
#  'tzarboi': 0.0,
#  'kurt6034': 0.0,
#  'mercanabdullah4': 0.0,
#  'polisidris': 0.0,
#  'nuribaskapan_53': 0.0,
#  'enezzz35': 0.0,
#  'cobanyildizi84': 1.0,
#  'syavan5': 0.0,
#  'aaslanbusraaa': 0.0,
#  'siganite': 1.0,
#  'hur_yasadim': 0.0,
#  'busraberr': 0.0,
#  '1mehmetkaracatr': 0.0,
#  'breadycheekstae': 0.0,
#  'typdnz': 0.0,
#  'kasmabosver': 0.0,
#  'fatiheygihan': 0.0,
#  'baykrall3': 0.0,
#  'betxzhng9': 0.0,
#  'melikeouzz': 0.0,
#  '7_braveheart_77': 0.0,
#  'berfubaysal': 0.0,
#  'turgut_demirer': 0.0,
#  'glfidankr': 1.0,
#  'twinwolves3': 0.0,
#  'ahmet_baykuss': 0.0,
#  'roses22autumun': 0.0,
#  'aleynacetinerrr': 0.0,
#  'ertbktsglu': 1.0,
#  '_col___': 0.0,
#  'eythayrullah': 0.0,
#  'karapapak_kk': 1.0,
#  'fflipovic': 0.0,
#  '_uyumayanlardan': 0.0,
#  'seabenmug': 0.0,
#  'ucurbenispqydi': 0.0,
#  'mineozyurt1': 0.0,
#  'amorti_kazim_': 0.0,
#  '19kayatugba03': 0.0,
#  'fenerli_voltran': 0.0,
#  'kediiseverim': 0.0,
#  'serhanfensoy31': 0.0,
#  'onlyonyaz': 1.0,
#  'mralilebanon': 0.0,
#  'meraleken': 0.0,
#  'esraaknvuk': 0.0,
#  'reaskerlin': 0.0,
#  'yakupayan6161': 0.0,
#  'mtemel01': 0.0,
#  'fernandoo1492': 0.0,
#  'pqueenn': 0.0,
#  'cetenakali': 0.0,
#  'karakurt2147': 0.0,
#  'mhd_dikici': 0.0,
#  'burak_eksii': 1.0,
#  'yigitkaaradag': 0.0,
#  'hayrettind59': 0.0,
#  'hakan1946893045': 1.0,
#  'dideem_a': 0.0,
#  'ridvanerdem1453': 0.0,
#  'alpdml': 0.0,
#  'hakyolu1735': 0.0,
#  'saksmavisimsisi': 0.0,
#  'ekremyildiz000': 0.0,
#  'elanuryillmaaz': 0.0,
#  'mustafa_dgrv': 0.0,
#  'aycaergerii': 0.0,
#  'elifcanimx': 1.0,
#  'hizmetissendika': 0.0,
#  'erkan52253919': 0.0,
#  'divanehep': 0.0,
#  'kaptanoglukemal': 0.0,
#  'mazlumadam5': 1.0,
#  'tokdemirismet': 0.0,
#  'abibizbittik': 1.0,
#  'aksevda37757072': 0.0,
#  'publichaber': 0.0,
#  'yasinaktimur': 0.0,
#  'yprkdkmu': 0.0,
#  'f_fatmazell': 0.0,
#  'skarnicaoglu': 1.0,
#  'yenigastecom': 0.0,
#  'sehzadeshizle': 0.0,
#  'barca9anil': 0.0,
#  'laaviiniiaax': 0.0,
#  'reismustafa1972': 0.0,
#  'elvanturkoglu': 0.0,
#  'bjorx5': 0.0,
#  'sadadadfagag': 0.0,
#  'bbobasket': 0.0,
#  'fthks_': 0.0,
#  'blackiequeenie': 0.0,
#  'fanatikilhan': 1.0,
#  'cardialement': 0.0,
#  'dilekkenc': 0.0,
#  'yaseminimlove': 0.0,
#  'faakara': 0.0,
#  'applesibell': 0.0,
#  'hsnpln1907': 0.0,
#  'chedi2020': 0.0,
#  'doasoylu5': 0.0,
#  'birazbens': 0.0,
#  '__mrymkyl1934__': 0.0,
#  'erzalid': 0.0,
#  'nailnabiulla': 0.0,
#  'mevlut0692': 0.0,
#  'gazali09814179': 1.0,
#  'korkusuz0113': 0.0,
#  'serdaracar16': 0.0,
#  'acibber5': 1.0,
#  '1pluviophilee': 0.0,
#  'dlimvi': 0.0,
#  'ohmyoshii': 0.0,
#  'seryass_gs': 0.0,
#  'esdwdea': 0.0,
#  'baybarskaramola': 0.0,
#  'erefeki21919886': 0.0,
#  'deryabalaban': 0.0,
#  'zceydaak': 0.0,
#  '014delimine': 1.0,
#  '__m__k__a__': 0.0,
#  'mustafa93391233': 1.0,
#  'izo15892778': 0.0,
#  'ustam79119271': 0.0,
#  'fuatkync63': 0.0,
#  'halit23594932': 0.0,
#  'edocumderler': 0.0,
#  'sogukcennet': 0.0,
#  'derdiyarolan': 0.0,
#  '_dayikaraeski': 0.0,
#  'slotherebaris06': 1.0,
#  'emineborsa': 0.0,
#  'elfimanyakfc': 0.0,
#  'filizdrm': 0.0,
#  'mamkamrey10': 0.0,
#  'mrt_gnaydin': 1.0,
#  'pamuk_skerr': 0.0,
#  'parkjungoriaxty': 0.0,
#  'gulcanhilaloglu': 0.0,
#  'julianspancakes': 0.0,
#  'layzhangs_xback': 0.0,
#  'birnevinevin': 0.0,
#  'kemalgulger': 0.0,
#  'vicdanliyolcu': 0.0,
#  'ankabangtan': 0.0,
#  'pusula61': 0.0,
#  'msarikaya6': 0.0,
#  'resmiplaka': 0.0,
#  'son_vatandas': 0.0,
#  'sikefil': 0.0,
#  'onbasj': 0.0,
#  'mkassoldiers': 0.0,
#  'kilimci': 0.0,
#  'reit85419015': 0.0,
#  'lebesi2': 0.0,
#  'neslihankaya35': 0.0,
#  'sero55_': 0.0,
#  'mugeertan06': 0.0,
#  'furkicanab': 0.0,
#  'haldunduran60': 0.0,
#  'albertin_kyp': 0.0,
#  'mellianagrande': 0.0,
#  'karaca8_karaca': 0.0,
#  'tozanizm58': 1.0,
#  'nadir0505': 0.0,
#  'musa_atacan': 0.0,
#  'muhtesem36': 0.0,
#  'hsnbozkurt': 0.0,
#  'xaea_xiyasin': 0.0,
#  'berivandgdvrn': 0.0,
#  'galaaycan': 0.0,
#  'hkn119761': 0.0,
#  'sevdeert': 0.0,
#  'kriptoemre': 0.0,
#  'zeyzen_16': 0.0,
#  'direnchinho62': 0.0,
#  'noluyotv': 0.0,
#  'simalbltt': 0.0,
#  'nomulonli': 0.0,
#  'sezer28845220': 0.0,
#  'dytnur1155': 0.0,
#  'yzehrak': 0.0,
#  'okay716': 1.0,
#  'ismet20909907': 0.0,
#  'harbalii17': 0.0,
#  'leylademirbas28': 0.0,
#  'deryayanikashb': 0.0,
#  'ahugzlr1907': 0.0,
#  'neslissssss': 0.0,
#  'arashsyn': 0.0,
#  'sevilaycelen1_': 0.0,
#  'damla21217627': 0.0,
#  'moonofgirl': 0.0,
#  'mehmetsalihzer6': 1.0,
#  'mustafaa_bodur': 0.0,
#  'dgeyikcioglu': 0.0,
#  'onuruluta14': 1.0,
#  'yasemin51440695': 0.0,
#  'hrj027': 0.0,
#  'blkpnr': 0.0,
#  'fztdiyelim': 1.0,
#  'pkz1907fb': 0.0,
#  'marqiitos25': 0.0,
#  'vbaybarsbilim': 0.0,
#  'ziyanoldukzi': 0.0,
#  'berkay143718717': 0.0,
#  'berhanataoglu': 0.0,
#  'huseyinerad33': 0.0,
#  'evelemedeveleme': 0.0,
#  'mrcozmms': 0.0,
#  'gkhan60913960': 0.0,
#  'hsynyilmaz09': 0.0,
#  'aras_erat': 0.0,
#  'guzelbahceak': 1.0,
#  '23ofer_': 0.0,
#  'koca3446': 0.0,
#  'hflzs': 0.0,
#  'chapulistanbul': 0.0,
#  'profesr47895600': 0.0,
#  'sebahattin_aks': 0.0,
#  'bora_bora__': 1.0,
#  'eytcan34': 0.0,
#  'tecdeli7144': 1.0,
#  'brk_u': 0.0,
#  'bayram_dnc_': 0.0,
#  'halukoz1991': 0.0,
#  'burjuvagardas1': 0.0,
#  'dilekif99736293': 0.0,
#  'rasitaydin': 0.0,
#  'mustiusta': 0.0,
#  'hakim01808125': 1.0,
#  'tunahan2820': 0.0,
#  'seroin': 0.0,
#  'figentregun': 0.0,
#  'mkorkmaz62': 1.0,
#  'saltugbeyy': 0.0,
#  'akyenimahalle06': 0.0,
#  'akpartiordu': 0.0,
#  'anzo_otto': 0.0,
#  'fbetulylmz53': 0.0,
#  'sahincetin01': 0.0,
#  'enesrar_': 0.0,
#  '27aykutkaya': 0.0,
#  'ssudelicious': 0.0,
#  'inzayntan': 0.0,
#  'dnzbkmdrg': 0.0,
#  'joker_jokic': 0.0,
#  'kkadirdayan': 1.0,
#  'agencyoffener': 0.0,
#  'nilgunbrbr': 1.0,
#  'kamiltekdal': 0.0,
#  'muratonukem': 1.0,
#  'mucahitce': 0.0,
#  'karhacerkar': 0.0,
#  'koraytopcu2': 0.0,
#  'hatungltekin1': 0.0,
#  'ylesineylesine2': 0.0,
#  'karamelam2005': 1.0,
#  'branan90070019': 0.0,
#  'genemibankaci': 0.0,
#  'siirkur': 0.0,
#  '09taner': 0.0,
#  'hadi_oradannn': 0.0,
#  'gndseyda': 0.0,
#  'saturnmars7': 0.0,
#  'dyucel4': 0.0,
#  'bisusunbeaq': 0.0,
#  'twister04240789': 1.0,
#  'dlwlrma2610': 0.0,
#  'meltem_1212_': 0.0,
#  'osmanosmanbzkrt': 0.0,
#  'infity03': 0.0,
#  'leylademirbas60': 0.0,
#  'chivasruhu': 0.0,
#  'umutdastan29': 0.0,
#  'minebasdogan': 0.0,
#  'verdayarkadas': 0.0,
#  'mehmete39577708': 0.0,
#  'ahmet61852332': 0.0,
#  'bkscambalkon': 0.0,
#  'mmeloooooo': 0.0,
#  'tv_stari': 1.0,
#  'karakar47092090': 0.0,
#  'harve65': 0.0,
#  'engtchrrahime': 0.0,
#  'hnazhu': 0.0,
#  'asahoooyy': 1.0,
#  'ertugrulcetin06': 0.0,
#  'antalya_biblo': 0.0,
#  'fallingforgot7': 0.0,
#  'kotramurat': 1.0,
#  'ilteriskaganx': 0.0,
#  'alidorukberke': 1.0,
#  'klcysfyusuf': 0.0,
#  'ismihanisik': 0.0,
#  'zcanbekli': 0.0,
#  'esragokbayguner': 0.0,
#  'mesmitch': 0.0,
#  'srplekc': 1.0,
#  'sinirlii0': 0.0,
#  'erdal_analiz': 1.0,
#  '1bugrastar': 0.0,
#  'zeynepaakdag': 0.0,
#  'sahila_aslanova': 0.0,
#  'slckylmzr': 0.0,
#  'devrani04': 0.0,
#  '404alis': 0.0,
#  'lafrodizyak': 0.0,
#  'glay48142411': 0.0,
#  'chanbaekrealbb': 0.0,
#  'magicandloss3': 0.0,
#  'mehmettatay63': 1.0,
#  'millimuhafiz10': 0.0,
#  'zlemmkya': 1.0,
#  'advocacy_human': 0.0,
#  'filaligs2': 0.0,
#  'simonpfirsich': 1.0,
#  '_cemileciritt': 0.0,
#  'ertugrul4535': 1.0,
#  'abdulla80969694': 0.0,
#  'laptoplugezgin': 0.0,
#  'webtekno': 0.0,
#  'feyzsn1': 0.0,
#  'floayakkabi': 0.0,
#  'bullishtrader_': 0.0,
#  'cabulbul': 0.0,
#  'cirkinoglu': 0.0,
#  'medyablok': 0.0,
#  'ertem_1905': 0.0,
#  '1ismetozel': 0.0,
#  'pearlofice': 0.0,
#  'orhantokgozz': 0.0,
#  'oykuarica': 0.0,
#  'reis10g': 1.0,
#  'my00ng1st': 0.0,
#  'memduhunluoglu': 0.0,
#  'mehmetbalkc': 0.0,
#  'mesudeunal33': 0.0,
#  '_195d': 0.0,
#  'elzoy3': 0.0,
#  'sadkeleb2': 0.0,
#  'sandy_zwane': 0.0,
#  'ayisigi1907': 0.0,
#  'dilanee': 0.0,
#  'milliciyiz': 0.0,
#  'zo11bb': 0.0,
#  'pdhanim': 0.0,
#  'cemal_toptanc21': 0.0,
#  'gamzeakrsuu': 0.0,
#  'mehtapp_mt': 0.0,
#  'afilifedailer': 0.0,
#  'bram_pablo': 0.0,
#  'osmanpertek': 0.0,
#  'lostvincent_': 0.0,
#  'olgunciftizbiz': 0.0,
#  'fbadurlu': 0.0,
#  'theotherboleyn1': 0.0,
#  'bolingolimbombo': 0.0,
#  'teke_fatma': 0.0,
#  'kukuli08': 0.0,
#  'deliyevuruyorum': 0.0,
#  'chequevera06': 0.0,
#  'aliayc01': 0.0,
#  'reis_gam': 1.0,
#  'osmanli10712071': 0.0,
#  'newrotik61': 0.0,
#  'joe11710': 1.0,
#  'onur37260242': 1.0,
#  'yavuzsubasi': 0.0,
#  'alboranhc': 1.0,
#  'birsen__kcktrk': 0.0,
#  'ahmet__bumin': 0.0,
#  'eyt_hb': 0.0,
#  '___gultoplayan': 0.0,
#  'selenophilefida': 1.0,
#  'dytaysekrz': 0.0,
#  'anna246522334': 1.0,
#  'glnur02562467': 0.0,
#  'ali_incebay': 0.0,
#  'ultsooyas': 0.0,
#  'konuralphuseyin': 0.0,
#  'benfcyus1': 0.0,
#  'vatanummet': 1.0,
#  'ikidirekarasi': 0.0,
#  'bullsionzi': 0.0,
#  'godofwinee': 0.0,
#  'daffodilera': 0.0,
#  'bfk1903': 0.0,
#  'ikbalesarikaya': 0.0,
#  'ender1973olako1': 0.0,
#  'zeynelabidingll': 0.0,
#  'geronimoapo': 0.0,
#  'lindoaspero': 0.0,
#  'antikacidahi': 0.0,
#  'my127s': 0.0,
#  'pardonsabina': 1.0,
#  'yunusemrefcsevg': 0.0,
#  'vizyonsuzali': 0.0,
#  'kkirazserkan': 0.0,
#  'the__erkan': 0.0,
#  'atillab3y': 1.0,
#  'sunduzsimsek': 0.0,
#  'basakozkan16': 1.0,
#  'r_kayaaa': 0.0,
#  '28sabrikontek': 0.0,
#  '36bucuktae': 0.0,
#  'r0ad_runn3r': 1.0,
#  'ahmetkurolu1': 1.0,
#  'hamza143738514': 0.0,
#  'bahar_geldimi': 0.0,
#  'alpayonalann': 0.0,
#  'iremgulkaratas': 0.0,
#  'avercanezgn': 0.0,
#  'halitcanbolat': 0.0,
#  'yikik_biriydim': 1.0,
#  'sadecenadide': 0.0,
#  'aliburakdede1': 0.0,
#  'nurcannar18': 1.0,
#  'hacer34_61': 0.0,
#  'anlatdinliyo': 0.0,
#  'pramuhtialll': 0.0,
#  'pubghesap1997': 0.0,
#  'ordu5grup': 0.0,
#  'loveepiphanyy': 0.0,
#  'demirkazk5': 1.0,
#  'seyit0v': 0.0,
#  'difteriaa': 0.0,
#  'cnworldwidenews': 0.0,
#  'chillchords': 0.0,
#  'bakrebu': 0.0,
#  'vahitatalan': 0.0,
#  'gaksu2525': 0.0,
#  'haberx': 0.0,
#  'saimdolanbay': 1.0,
#  'bircan_durmazz': 0.0,
#  'niisaannnn': 0.0,
#  'zgrcann71': 0.0,
#  'ramazan_uzunoz': 0.0,
#  'h_nuhoglu': 0.0,
#  'mervenrkaratas': 1.0,
#  'haberistan0': 0.0,
#  'serknylmaz': 0.0,
#  'goidenioved': 0.0,
#  'ilkeretinkaya16': 0.0,
#  'kwanrv': 0.0,
#  'huzunkovann1': 1.0,
#  'orernursel': 0.0,
#  'gsb_agri': 0.0,
#  'memozin1299': 0.0,
#  'weycellbey': 1.0,
#  'olay53rize': 0.0,
#  'yakupuc87313685': 0.0,
#  'eraydundar2784': 1.0,
#  'akg5361': 0.0,
#  'mustfaaa1919': 1.0,
#  'vsendikas': 0.0,
#  'sk_futbol': 1.0,
#  'seyyidkose': 0.0,
#  'howraidenruzgar': 0.0,
#  'cnatbz': 1.0,
#  'kald_fadime': 1.0,
#  'fatihkucuuk': 0.0,
#  'glsm30150343': 0.0,
#  'milliey__': 0.0,
#  'fundakaraaslan9': 0.0,
#  'gulsencengizzz': 0.0,
#  'mertdurmazon': 0.0,
#  'hasibeincidal1': 1.0,
#  'nurnur1974': 0.0,
#  'evginsude': 0.0,
#  'mroizox': 0.0,
#  'omerfarukgorcin': 0.0,
#  'tengrikut58': 0.0,
#  'uzgunbiri__': 0.0,
#  'sehercanii': 0.0,
#  'kpssedebiiyat': 1.0,
#  'eminekorglu_': 0.0,
#  'nazamar522': 0.0,
#  '_____klcby_____': 0.0,
#  'seyherol': 0.0,
#  'ahmetyl76139628': 0.0,
#  'camist91': 0.0,
#  'bisaniyeyaaaaaa': 1.0,
#  'alpinyomylove': 1.0,
#  'atticus32690416': 0.0,
#  'brtbzr41': 0.0,
#  'hhihigh': 0.0,
#  'rabia5377': 0.0,
#  'molumehmet': 0.0,
#  '_zehracicek': 0.0,
#  'phemre': 0.0,
#  'hardenmagics': 0.0,
#  'sirerkkk': 1.0,
#  'alioztas0632': 0.0,
#  'seneryusuf02': 1.0,
#  'esra_ozkeskin': 0.0,
#  'acilsecim': 0.0,
#  '19yirni': 0.0,
#  'sumdiyolarr': 1.0,
#  'alifirat1907': 0.0,
#  'arcturuseq': 0.0,
#  'doan14040813': 1.0,
#  'ayenurinan': 0.0,
#  'erl2023': 0.0,
#  'sridhar_sw': 0.0,
#  'sizenekardsm': 0.0,
#  'tulaypekince': 0.0,
#  'rainsound02': 0.0,
#  'gkhanarass': 0.0,
#  '1990_htc': 0.0,
#  'halletn15': 0.0,
#  'ttugbaerol1': 0.0,
#  'ckyunum': 0.0,
#  'seproduire': 0.0,
#  'idontcarecutie': 0.0,
#  'yildizfatos1': 0.0,
#  'senligeceler': 0.0,
#  'mustafasatil': 1.0,
#  'ermoxx': 0.0,
#  'themonkyg': 0.0,
#  'ilhami58330752': 0.0,
#  'fzeyneep': 0.0,
#  'bbasbayraktar': 0.0,
#  'haticeciriss': 0.0,
#  'meb6307': 0.0,
#  'duhuliyecomtr': 0.0,
#  'hiiamsum': 0.0,
#  'erkanzg66699576': 0.0,
#  'fatihozcan_gs': 0.0,
#  'murat44sle': 0.0,
#  'atahancaylak': 0.0,
#  'rkaraca9': 1.0,
#  'sonkamuhaber': 0.0,
#  'nurullahelci': 0.0,
#  'ilostinmemories': 0.0,
#  'askobeybsi': 0.0,
#  'mesafeuzmani': 0.0,
#  'cem_savan_': 0.0,
#  'hanturkeshan': 0.0,
#  'qlyv_nrln': 0.0,
#  'tesbihliabi': 0.0,
#  'zynbamre': 0.0,
#  'ayansedanurr': 0.0,
#  'puraldemi': 0.0,
#  'muhendisahmett': 0.0,
#  'beytullahkumser': 0.0,
#  'uurgoksen1': 0.0,
#  'malignaydin72': 0.0,
#  'seungjinswift': 0.0,
#  'biroltastan06': 0.0,
#  'ertan5304': 0.0,
#  'isimveesoyisim': 0.0,
#  ...}

# %% [markdown]
# # PREPARE SUBMISSION

# %% [markdown]
# You will need to submit exact same file produced by using the following code. Any deviation from the desired format willbe marked as 0.

# %%
with open('{}/{}-round{}-tweet.txt'.format(DATA_PATH, STUDENT_ID, ROUND), 'w') as fl:
    fl.write('{} - {}\n'.format(STUDENT_ID, PROJECT_CODE))
    fl.write(json.dumps(modelPredTweet))
    
    
with open('{}/{}-round{}-user.txt'.format(DATA_PATH, STUDENT_ID, ROUND), 'w') as fl:
    fl.write('{} - {}\n'.format(STUDENT_ID, PROJECT_CODE))
    fl.write(json.dumps(modelPredUser))

# %%
display.Image("https://i.imgur.com/lcwRsOW.png")

# %%
display.Image("https://i.imgur.com/qfxqgMF.png")

# %% [markdown]
# You can check whether you can read your predictions correctly or not:

# %%
with open('{}/{}-round{}-tweet.txt'.format(DATA_PATH, STUDENT_ID, ROUND), 'r') as fl:
    file = fl.read()

student_info = file.split("\n")[0]
predictions = eval(file.split("\n")[1])
